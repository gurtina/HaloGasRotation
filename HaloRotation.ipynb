# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from astropy.coordinates import SkyCoord
from astropy import units as u
from matplotlib.colors import LogNorm

# %%
data = np.zeros((37,4))

# %%
# Data from Hodges-Kluck 2016
# https://iopscience.iop.org/article/10.3847/1538-4357/ab32eb/pdf
# used in Miller 2016 https://iopscience.iop.org/article/10.3847/0004-637X/818/2/112/pdf

# Mkn 421  
data[0,0]=179.832 # Gal Long (degrees)
data[0,1]= 65.031  # Gal Lat (degrees)
data[0,2]= -29 # Vo-vonc (difference bettwen heliocentric corrections vs non-corrected)
data[0,3] = -65 # Vo corrected +/- 21

# 3C 273 
data[1,0]=289.951-360 # Gal Long (degrees)
data[1,1]= 64.360  # Gal Lat (degrees)
data[1,2]= -27 # Vo-vonc (diff heliocentric corrections)
data[1,3] = 33 # Vo corrected

# PKS 2155-304 
data[2,0]=17.73 # Gal Long (degrees)
data[2,1]= -52.245  # Gal Lat (degrees)
data[2,2]= -33 # Vo-vonc (diff heliocentric corrections)
data[2,3] = -39 # Vo corrected


#Mkn 509
data[3,0]=35.971 # Gal Long (degrees)
data[3,1]= -29.855  # Gal Lat (degrees)
data[3,2]= -41 # Vo-vonc (heliocentric corrections)
data[3,3] = -45 # Vo corrected

#NGC 4051
data[4,0]=148.883 # Gal Long (degrees)
data[4,1]=70.085  # Gal Lat (degrees)
data[4,2]= 8 # Vo-vonc (heliocentric corrections)
data[4,3] = 110 # Vo corrected


#MCG -06-30-15
data[5,0]=313.292-360 # Gal Long (degrees)
data[5,1]=27.68  # Gal Lat (degrees)
data[5,2]= -1 # Vo-vonc (heliocentric corrections)
data[5,3] = 53 # Vo corrected


#Ark 564
data[6,0]=92.138 # Gal Long (degrees)
data[6,1]=-25.337  # Gal Lat (degrees)
data[6,2]= 21 # Vo-vonc (heliocentric corrections)
data[6,3] = -57 # Vo corrected

#ESO 141-55
data[7,0]=338.183-360 # Gal Long (degrees)
data[7,1]=-26.711  # Gal Lat (degrees)
data[7,2]= 102 # Vo-vonc (heliocentric corrections)
data[7,3] = -154 # Vo corrected


#H1426 + 428
data[8,0]=77.487 # Gal Long (degrees)
data[8,1]=64.899  # Gal Lat (degrees)
data[8,2]= -7 # Vo-vonc (heliocentric corrections)
data[8,3] = 83 # Vo corrected

# 1H 0707-495
data[9,0]=260.169-360 # Gal Long (degrees)
data[9,1]=-17.672 # Gal Lat (degrees)
data[9,2]= -21 # Vo-vonc (heliocentric corrections)
data[9,3] = 45 # Vo corrected


#PKS -558-504
data[10,0]=257.962-360 # Gal Long (degrees)
data[10,1]=-28.569  # Gal Lat (degrees)
data[10,2]= 8 # Vo-vonc (heliocentric corrections)
data[10,3] = 7 # Vo corrected


#NGC 4593
data[11,0]=297.483-360 # Gal Long (degrees)
data[11,1]=57.403  # Gal Lat (degrees)
data[11,2]= 11 # Vo-vonc (heliocentric corrections)
data[11,3] = -63 # Vo corrected

#MRK 335
data[12,0]=108.763  # Gal Long (degrees)
data[12,1]=-41.424  # Gal Lat (degrees)
data[12,2]= -40 # Vo-vonc (heliocentric corrections)
data[12,3] = -161 # Vo corrected

# PG 1211+143
data[13,0]=267.552-360  # Gal Long (degrees)
data[13,1]=74.315  # Gal Lat (degrees)
data[13,2]= -57 # Vo-vonc (heliocentric corrections)
data[13,3] = -69 # Vo corrected

#PG 1244+026
data[14,0]=300.041-360  # Gal Long (degrees)
data[14,1]=65.214  # Gal Lat (degrees)
data[14,2]= -188 # Vo-vonc (heliocentric corrections)
data[14,3] = 130 # Vo corrected

#Mkn 501
data[15,0]= 64.6  # Gal Long (degrees)
data[15,1]= 38.86  # Gal Lat (degrees)
data[15,2]= -68 # Vo-vonc (heliocentric corrections)
data[15,3] = 41 # Vo corrected


#1ES 1028 + 511
data[16,0]=161.439  # Gal Long (degrees)
data[16,1]=54.439  # Gal Lat (degrees)
data[16,2]= 81 # Vo-vonc (heliocentric corrections)
data[16,3] = 40 # Vo corrected

# ESO 198-24
data[17,0]=271.639-360  # Gal Long (degrees)
data[17,1]=-57.439  # Gal Lat (degrees)
data[17,2]= -393 # Vo-vonc (heliocentric corrections)
data[17,3] = -652 # Vo corrected


# NGC 2617
data[18,0]= 229.3-360  # Gal Long (degrees)
data[18,1]= 20.939  # Gal Lat (degrees)
data[18,2]= -95 # Vo-vonc (heliocentric corrections)
data[18,3] = 58 # Vo corrected

# PG 1553+113
data[19,0]= 21.909  # Gal Long (degrees)
data[19,1]=43.964  # Gal Lat (degrees)
data[19,2]= 45 # Vo-vonc (heliocentric corrections)
data[19,3] = -149 # Vo corrected

# H1101-232
data[20,0]= 273.19 - 360  # Gal Long (degrees)
data[20,1]= 33.079  # Gal Lat (degrees)
data[20,2]= 2 # Vo-vonc (heliocentric corrections)
data[20,3] = 358 # Vo corrected

# 3C 390.3
data[21,0]=111.438  # Gal Long (degrees)
data[21,1]=27.074 # Gal Lat (degrees)
data[21,2]= -21 # Vo-vonc (heliocentric corrections)
data[21,3] = 130 # Vo corrected

# 1H 0419-577
data[22,0]= 266.963-360  # Gal Long (degrees)
data[22,1]= -42.006 # Gal Lat (degrees)
data[22,2]= 17 # Vo-vonc (heliocentric corrections)
data[22,3] = 783 # Vo corrected

# Fairall 9 (THIS GOES THROUGH THE STREAM)
data[23,0]= 295.073-360  # Gal Long (degrees)
data[23,1]= -57.826# Gal Lat (degrees)
data[23,2]= -226 # Vo-vonc (heliocentric corrections)
data[23,3] = -18 # Vo corrected

# IRAS 13224-3809
data[24,0]= 310.189-360  # Gal Long (degrees)
data[24,1]= 23.979 # Gal Lat (degrees)
data[24,2]= 31 # Vo-vonc (heliocentric corrections)
data[24,3] = -63 # Vo corrected

#  NGC 5408 X-1
data[25,0]= 317.149-360  # Gal Long (degrees)
data[25,1]= 19.496 # Gal Lat (degrees)
data[25,2]= -98 # Vo-vonc (heliocentric corrections)
data[25,3] = -19 # Vo corrected

# PDS 456 
data[26,0]= 10.392  # Gal Long (degrees)
data[26,1]= 11.164 # Gal Lat (degrees)
data[26,2]= 47 # Vo-vonc (heliocentric corrections)
data[26,3] = 57 # Vo corrected

# Mrk 279
data[27,0]= 115.042  # Gal Long (degrees)
data[27,1]= 46.865 # Gal Lat (degrees)
data[27,2]= -29 # Vo-vonc (heliocentric corrections)
data[27,3] = 58 # Vo corrected

# E1821 +643
data[28,0]= 94.003  # Gal Long (degrees)
data[28,1]= 27.417 # Gal Lat (degrees)
data[28,2]= -28 # Vo-vonc (heliocentric corrections)
data[28,3] = 85 # Vo corrected

# IC 4329A
data[29,0]= 317.496  # Gal Long (degrees)
data[29,1]= 30.92 # Gal Lat (degrees)
data[29,2]= -73 # Vo-vonc (heliocentric corrections)
data[29,3] = -93 # Vo corrected

# PG 0804+761
data[30,0]= 138.279  # Gal Long (degrees)
data[30,1]= 31.033 # Gal Lat (degrees)
data[30,2]= 98 # Vo-vonc (heliocentric corrections)
data[30,3] = 57 # Vo corrected

#  NGC 5548
data[31,0]= 31.960  # Gal Long (degrees)
data[31,1]= 70.496 # Gal Lat (degrees)
data[31,2]= -51 # Vo-vonc (heliocentric corrections)
data[31,3] = -46 # Vo corrected

# Mrk 766
data[32,0]= 190.681-180  # Gal Long (degrees)
data[32,1]= 82.27 # Gal Lat (degrees)
data[32,2]= 93 # Vo-vonc (heliocentric corrections)
data[32,3] = 191 # Vo corrected


#Local Sources
# LMC X3
data[33,0]= 273.576-360  # Gal Long (degrees)
data[33,1]= -32.082 # Gal Lat (degrees)
data[33,2]= 7 # Vo-vonc (heliocentric corrections)
data[33,3] = 35 # Vo corrected

# 4U 1957 + 11
data[34,0]= 51.308  # Gal Long (degrees)
data[34,1]= -9.33 # Gal Lat (degrees)
data[34,2]= -124 # Vo-vonc (heliocentric corrections)
data[34,3] = -264 # Vo corrected

# MAXI J0556-032
data[35,0]= 238.939-360  # Gal Long (degrees)
data[35,1]= -25.183 # Gal Lat (degrees)
data[35,2]=  84 # Vo-vonc (heliocentric corrections)
data[35,3] = 137 # Vo corrected

# SMC X-1
data[36,0]= 300.414-360  # Gal Long (degrees)
data[36,1]= -43.56 # Gal Lat (degrees)
data[36,2]= -3 # Vo-vonc (heliocentric corrections)
data[36,3] = 117 # Vo corrected

# %%
# Loading in the stream model 

# Galactic and Magellanic Stream Coordinates

# Original B12 
all = np.loadtxt('AllGasPos_Model1.txt')

# Corrected after the fact for K13 velocities
#all = np.loadtxt('AllGasPos_Model1_K13Correct.txt')

# Galactic l, b
lModel1 = all[:,0] 
bModel1 = all[:,1]

# %%
lmod1 = lModel1
lmod1[np.where(lModel1>180)] = lmod1[np.where(lModel1>180)]-360

# %%
# Probably need to cut out the Magellanic Stream

# %%
# Plotting two hemisphere's together as in Miller 2016 


fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111, projection="mollweide")

#norm = matplotlib.colors.Normalize(vmin=min(data[:,3]),vmax=max(data[:,3]))
norm = matplotlib.colors.Normalize(vmin=-250, vmax=250) 

c_m = matplotlib.cm.bwr # RdBu # viridis
s_m = matplotlib.cm.ScalarMappable(cmap=c_m, norm=norm)
s_m.set_array([])


cbar = matplotlib.pyplot.colorbar(s_m,orientation="horizontal")
cbar.set_label('Vo-Vhelio')

idx = np.where(np.abs(data[:,3]) < 100)

#ax.scatter(data[idx[0],0]*u.deg.to(u.radian), data[idx[0],1]*u.deg.to(u.radian), c=s_m.to_rgba(data[idx[0],2]))
#ax.scatter(data[:,0]*u.deg.to(u.radian), data[:,1]*u.deg.to(u.radian), c=s_m.to_rgba(data[:,2]))

# both hemispheres
ax.scatter(data[:,0]*u.deg.to(u.radian), np.abs(data[:,1]*u.deg.to(u.radian)), c=s_m.to_rgba(data[:,3]))



ax.set_xticklabels([])

ax.xaxis.set_ticks([-np.pi, -np.pi/2., 0, np.pi/2., np.pi])
ax.xaxis.set_ticks([-np.pi, -3*np.pi/4., -np.pi/2., -np.pi/4.\
                    ,0, np.pi/4. ,np.pi/2., 3*np.pi/4., np.pi],\
                    minor=True)

ax.yaxis.set_ticks([ -np.pi/2.1, 0, np.pi/2.1], minor=True)


#adjust tick label font size
label_size = 15
matplotlib.rcParams['xtick.labelsize'] = label_size 
matplotlib.rcParams['ytick.labelsize'] = label_size


# labels for Galactic l
ax.text(-np.pi/1.0, 0.01, '-$180^{\circ}$',size=15)
ax.text(-np.pi/2.1, 0.01, '-$90^{\circ}$',size=15)
ax.text(0.0, 0.01, '$0^{\circ}$',size=15)
ax.text(np.pi/2.0, 0.01, '$90^{\circ}$',size=15)
ax.text(np.pi/1.25, 0.01, '$180^{\circ}$',size=15)

ax.grid(which='major')
ax.grid(which='minor')


#savefig('../../../MW_anisotropy/figures/LMC_orbit_aitoff.png', bbox_inches='tight', dpi=150)
#plt.savefig('Mollweide_Model1_June_V2.png', format='png', dpi=350)

# %% [markdown]
# ![alt text](Miller2016.png "Miller") Figure from Miller 2016. Top is data bottom is corresponding rotation model .

# %%
# Mollweide 
# Same as above but now separating out the hemispheres


fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111, projection="mollweide")

#norm = matplotlib.colors.Normalize(vmin=min(data[:,3]),vmax=max(data[:,3]))
norm = matplotlib.colors.Normalize(vmin=-250, vmax=250) 

c_m = matplotlib.cm.bwr # RdBu # viridis
s_m = matplotlib.cm.ScalarMappable(cmap=c_m, norm=norm)
s_m.set_array([])


cbar = matplotlib.pyplot.colorbar(s_m,orientation="horizontal")
cbar.set_label('Vo-Vhelio')

idx = np.where(np.abs(data[:,3]) < 100)

#ax.scatter(data[idx[0],0]*u.deg.to(u.radian), data[idx[0],1]*u.deg.to(u.radian), c=s_m.to_rgba(data[idx[0],3]))
ax.scatter(data[:,0]*u.deg.to(u.radian), data[:,1]*u.deg.to(u.radian), c=s_m.to_rgba(data[:,3]))

# both hemispheres
#ax.scatter(data[:,0]*u.deg.to(u.radian), np.abs(data[:,1]*u.deg.to(u.radian)), c=s_m.to_rgba(data[:,3]))



ax.set_xticklabels([])

ax.xaxis.set_ticks([-np.pi, -np.pi/2., 0, np.pi/2., np.pi])
ax.xaxis.set_ticks([-np.pi, -3*np.pi/4., -np.pi/2., -np.pi/4.\
                    ,0, np.pi/4. ,np.pi/2., 3*np.pi/4., np.pi],\
                    minor=True)

ax.yaxis.set_ticks([ -np.pi/2.1, 0, np.pi/2.1], minor=True)


#adjust tick label font size
label_size = 15
matplotlib.rcParams['xtick.labelsize'] = label_size 
matplotlib.rcParams['ytick.labelsize'] = label_size


# labels for Galactic l
ax.text(-np.pi/1.0, 0.01, '-$180^{\circ}$',size=15)
ax.text(-np.pi/2.1, 0.01, '-$90^{\circ}$',size=15)
ax.text(0.0, 0.01, '$0^{\circ}$',size=15)
ax.text(np.pi/2.0, 0.01, '$90^{\circ}$',size=15)
ax.text(np.pi/1.25, 0.01, '$180^{\circ}$',size=15)

ax.grid(which='major')
ax.grid(which='minor')


#savefig('../../../MW_anisotropy/figures/LMC_orbit_aitoff.png', bbox_inches='tight', dpi=150)
#plt.savefig('Mollweide_Model1_June_V2.png', format='png', dpi=350)

# %%
# Same as above but taking out the highest velocity values. 
# (> 100 km/s) where the reflex motion will have less of an impact 


fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111, projection="mollweide")

#norm = matplotlib.colors.Normalize(vmin=min(data[:,3]),vmax=max(data[:,3]))
norm = matplotlib.colors.Normalize(vmin=-100, vmax=100) 

c_m = matplotlib.cm.bwr # RdBu # viridis
s_m = matplotlib.cm.ScalarMappable(cmap=c_m, norm=norm)
s_m.set_array([])


cbar = matplotlib.pyplot.colorbar(s_m,orientation="horizontal")
cbar.set_label('Vo-Vhelio')

idx = np.where(np.abs(data[:,3]) < 100)

ax.scatter(data[idx[0],0]*u.deg.to(u.radian), data[idx[0],1]*u.deg.to(u.radian), c=s_m.to_rgba(data[idx[0],3]))
#ax.scatter(data[:,0]*u.deg.to(u.radian), data[:,1]*u.deg.to(u.radian), c=s_m.to_rgba(data[:,3]))

# both hemispheres
#ax.scatter(data[:,0]*u.deg.to(u.radian), np.abs(data[:,1]*u.deg.to(u.radian)), c=s_m.to_rgba(data[:,3]))



ax.set_xticklabels([])

ax.xaxis.set_ticks([-np.pi, -np.pi/2., 0, np.pi/2., np.pi])
ax.xaxis.set_ticks([-np.pi, -3*np.pi/4., -np.pi/2., -np.pi/4.\
                    ,0, np.pi/4. ,np.pi/2., 3*np.pi/4., np.pi],\
                    minor=True)

ax.yaxis.set_ticks([ -np.pi/2.1, 0, np.pi/2.1], minor=True)


#adjust tick label font size
label_size = 15
matplotlib.rcParams['xtick.labelsize'] = label_size 
matplotlib.rcParams['ytick.labelsize'] = label_size


# labels for Galactic l
ax.text(-np.pi/1.0, 0.01, '-$180^{\circ}$',size=15)
ax.text(-np.pi/2.1, 0.01, '-$90^{\circ}$',size=15)
ax.text(0.0, 0.01, '$0^{\circ}$',size=15)
ax.text(np.pi/2.0, 0.01, '$90^{\circ}$',size=15)
ax.text(np.pi/1.25, 0.01, '$180^{\circ}$',size=15)

ax.grid(which='major')
ax.grid(which='minor')


#savefig('../../../MW_anisotropy/figures/LMC_orbit_aitoff.png', bbox_inches='tight', dpi=150)
#plt.savefig('Mollweide_Model1_June_V2.png', format='png', dpi=350)

# %% [markdown]
# ![alt text](45kpc_Garavito.png "Garavito2019_Fig9BottomRight_45kpc")
# Fig 9 from Garavito-Camargo 2019 (bottom right panel, Vrad at 45 kpc). LMC is to bottom left.  Scale is. +/- 40 km/s
#
# ![alt text](Garavito_70kpc.png "Garavito2019_Fig10BottomRight_70kpc")
# Fig 10 from Garavito-Camargo 2019 (bottom right panel, Vrad at 70 kpc). Scale is now +/- 80 km/s
#
# https://iopscience.iop.org/article/10.3847/1538-4357/ab32eb/pdf
#
# See also Cunningham 2020 https://arxiv.org/pdf/2006.08621.pdf

# %%
# Mollweide Of Model 1 Magellanic Cloud Sim from Besla 2012 for reference 


fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111, projection="mollweide")




#norm = matplotlib.colors.Normalize(vmin=min(data[:,2]),vmax=max(data[:,2]))
#norm = matplotlib.colors.Normalize(vmin=-50, vmax=50) 

c_m = matplotlib.cm.magma # RdBu # viridis
s_m = matplotlib.cm.ScalarMappable(cmap=c_m, norm=LogNorm())
s_m.set_array([])

#ax.scatter(l*u.deg.to(u.radian), b*u.deg.to(u.radian))
#ax.hist2d(lmod1*u.deg.to(u.radian), b*u.deg.to(u.radian), bins=500, norm=LogNorm(), cmap='magma')
ax.hist2d(lmod1*u.deg.to(u.radian), b*u.deg.to(u.radian), bins=500, norm=LogNorm(), cmap='magma')


#cbar = matplotlib.pyplot.colorbar(s_m,orientation="horizontal")
#cbar.set_label('Vo-Vhelio')

#ax.scatter(data[:,0]*u.deg.to(u.radian), data[:,1]*u.deg.to(u.radian), c=s_m.to_rgba(data[:,2]))



ax.set_xticklabels([])

ax.xaxis.set_ticks([-np.pi, -np.pi/2., 0, np.pi/2., np.pi])
ax.xaxis.set_ticks([-np.pi, -3*np.pi/4., -np.pi/2., -np.pi/4.\
                    ,0, np.pi/4. ,np.pi/2., 3*np.pi/4., np.pi],\
                    minor=True)

ax.yaxis.set_ticks([ -np.pi/2.1, 0, np.pi/2.1], minor=True)


#adjust tick label font size
label_size = 15
matplotlib.rcParams['xtick.labelsize'] = label_size 
matplotlib.rcParams['ytick.labelsize'] = label_size


# labels for Galactic l
ax.text(-np.pi/1.0, 0.01, '-$180^{\circ}$',size=15)
ax.text(-np.pi/2.1, 0.01, '-$90^{\circ}$',size=15)
ax.text(0.0, 0.01, '$0^{\circ}$',size=15)
ax.text(np.pi/2.0, 0.01, '$90^{\circ}$',size=15)
ax.text(np.pi/1.25, 0.01, '$180^{\circ}$',size=15)

ax.grid(which='major')
ax.grid(which='minor')


#savefig('../../../MW_anisotropy/figures/LMC_orbit_aitoff.png', bbox_inches='tight', dpi=150)
#plt.savefig('Mollweide_Model1_June_V2.png', format='png', dpi=350)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-2eab5e83f254> in <module>
#      17 #ax.scatter(l*u.deg.to(u.radian), b*u.deg.to(u.radian))
#      18 #ax.hist2d(lmod1*u.deg.to(u.radian), b*u.deg.to(u.radian), bins=500, norm=LogNorm(), cmap='magma')
# ---> 19 ax.hist2d(lmod1*u.deg.to(u.radian), b*u.deg.to(u.radian), bins=500, norm=LogNorm(), cmap='magma')
#      20
#      21
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
# ...
